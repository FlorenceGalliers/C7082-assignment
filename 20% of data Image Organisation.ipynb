# %%
import os, shutil

# %%
# The path to the directory where the original dataset was uncompressed
original_dataset_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data'

# The directory where we will store our smaller dataset
base_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/pre-data'
#os.mkdir(base_dir)

# %%
# Directories for our training, validation and test splits
train_dir = os.path.join(base_dir, 'train')
#os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
#os.mkdir(validation_dir)
#test_dir = os.path.join(base_dir, 'test')
#os.mkdir(test_dir)

# %% [markdown]
# Black Grass Directories and Images

# %%
# Directory with our training bgs pictures
train_bgs_dir = os.path.join(train_dir, 'bgs')
# Directory with our validation bgs pictures
#os.mkdir(train_bgs_dir)
validation_bgs_dir = os.path.join(validation_dir, 'bgs')
#os.mkdir(validation_bgs_dir)
# Directory with our test bgs pictures
#test_bgs_dir = os.path.join(test_dir, 'bgs')
#os.mkdir(test_bgs_dir)

#original bgs data
original_bgs_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/black-grass'

# Copy first 50 bgs images to train_bgs_dir
fnames = ['bgs_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_bgs_dir, fname)
    dst = os.path.join(train_bgs_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 bgs images to validation_bgs_dir
fnames = ['bgs_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_bgs_dir, fname)
    dst = os.path.join(validation_bgs_dir, fname)
    shutil.copyfile(src, dst)
    
# Copy next 25 bgs images to test_bgs_dir
#fnames = ['bgs_{}.png'.format(i) for i in range(284, 309)]
#for fname in fnames:
 #   src = os.path.join(original_bgs_dir, fname)
  #  dst = os.path.join(test_bgs_dir, fname)
   # shutil.copyfile(src, dst)

# %% [markdown]
# Charlock Directories and Images

# %%
# Directory with our training chk pictures
train_chk_dir = os.path.join(train_dir, 'chk')
os.mkdir(train_chk_dir)
# Directory with our validation chk pictures
validation_chk_dir = os.path.join(validation_dir, 'chk')
os.mkdir(validation_chk_dir)

#original chk data
original_chk_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/charlock'

# Copy first 50 chk images to train_chk_dir
fnames = ['chk_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_chk_dir, fname)
    dst = os.path.join(train_chk_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 chk images to validation_chk_dir
fnames = ['chk_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_chk_dir, fname)
    dst = os.path.join(validation_chk_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Cleavers Directories and Images

# %%
# Directory with our training cls pictures
train_cls_dir = os.path.join(train_dir, 'cls')
os.mkdir(train_cls_dir)
# Directory with our validation cls pictures
validation_cls_dir = os.path.join(validation_dir, 'cls')
os.mkdir(validation_cls_dir)

#original cls data
original_cls_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/cleavers'

# Copy first 50 cls images to train_cls_dir
fnames = ['cls_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_cls_dir, fname)
    dst = os.path.join(train_cls_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 cls images to validation_cls_dir
fnames = ['cls_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_cls_dir, fname)
    dst = os.path.join(validation_cls_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Common Chickweed Directories and Images

# %%
# Directory with our training cwd pictures
train_cwd_dir = os.path.join(train_dir, 'cwd')
os.mkdir(train_cwd_dir)
# Directory with our validation cwd pictures
validation_cwd_dir = os.path.join(validation_dir, 'cwd')
os.mkdir(validation_cwd_dir)

#original cwd data
original_cwd_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/common-chickweed'

# Copy first 50 cwd images to train_cwd_dir
fnames = ['cwd_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_cwd_dir, fname)
    dst = os.path.join(train_cwd_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 cwd images to validation_cwd_dir
fnames = ['cwd_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_cwd_dir, fname)
    dst = os.path.join(validation_cwd_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Cranesbill Directories and Images

# %%
# Directory with our training cbl pictures
train_cbl_dir = os.path.join(train_dir, 'cbl')
os.mkdir(train_cbl_dir)
# Directory with our validation cbl pictures
validation_cbl_dir = os.path.join(validation_dir, 'cbl')
os.mkdir(validation_cbl_dir)

#original cbl data
original_cbl_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/cranesbill'

# Copy first 50 cbl images to train_cbl_dir
fnames = ['cbl_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_cbl_dir, fname)
    dst = os.path.join(train_cbl_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 cbl images to validation_cbl_dir
fnames = ['cbl_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_cbl_dir, fname)
    dst = os.path.join(validation_cbl_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Wheat Directories and Images

# %%
# Directory with our training wht pictures
train_wht_dir = os.path.join(train_dir, 'wht')
os.mkdir(train_wht_dir)
# Directory with our validation wht pictures
validation_wht_dir = os.path.join(validation_dir, 'wht')
os.mkdir(validation_wht_dir)

#original wht data
original_wht_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/common-wheat'

# Copy first 50 wht images to train_wht_dir
fnames = ['wht_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_wht_dir, fname)
    dst = os.path.join(train_wht_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 wht images to validation_wht_dir
fnames = ['wht_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_wht_dir, fname)
    dst = os.path.join(validation_wht_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Fat Hen Directories and Images

# %%
# Directory with our training fhn pictures
train_fhn_dir = os.path.join(train_dir, 'fhn')
os.mkdir(train_fhn_dir)
# Directory with our validation fhn pictures
validation_fhn_dir = os.path.join(validation_dir, 'fhn')
os.mkdir(validation_fhn_dir)

#original fhn data
original_fhn_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/fat-hen'

# Copy first 50 fhn images to train_fhn_dir
fnames = ['fhn_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_fhn_dir, fname)
    dst = os.path.join(train_fhn_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 fhn images to validation_fhn_dir
fnames = ['fhn_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_fhn_dir, fname)
    dst = os.path.join(validation_fhn_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Loose Silky Bent Directories and Images

# %%
# Directory with our training lsb pictures
train_lsb_dir = os.path.join(train_dir, 'lsb')
os.mkdir(train_lsb_dir)
# Directory with our validation lsb pictures
validation_lsb_dir = os.path.join(validation_dir, 'lsb')
os.mkdir(validation_lsb_dir)

#original lsb data
original_lsb_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/loose-silky-bent'

# Copy first 50 lsb images to train_lsb_dir
fnames = ['lsb_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_lsb_dir, fname)
    dst = os.path.join(train_lsb_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 lsb images to validation_lsb_dir
fnames = ['lsb_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_lsb_dir, fname)
    dst = os.path.join(validation_lsb_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Maize Directories and Images

# %%
# Directory with our training mze pictures
train_mze_dir = os.path.join(train_dir, 'mze')
os.mkdir(train_mze_dir)
# Directory with our validation mze pictures
validation_mze_dir = os.path.join(validation_dir, 'mze')
os.mkdir(validation_mze_dir)

#original mze data
original_mze_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/maize'

# Copy first 50 mze images to train_mze_dir
fnames = ['mze_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_mze_dir, fname)
    dst = os.path.join(train_mze_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 mze images to validation_mze_dir
fnames = ['mze_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_mze_dir, fname)
    dst = os.path.join(validation_mze_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Scentless Mayweed Directories and Images

# %%
# Directory with our training smw pictures
train_smw_dir = os.path.join(train_dir, 'smw')
os.mkdir(train_smw_dir)
# Directory with our validation smw pictures
validation_smw_dir = os.path.join(validation_dir, 'smw')
os.mkdir(validation_smw_dir)

#original smw data
original_smw_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/scentless-mayweed'

# Copy first 50 smw images to train_smw_dir
fnames = ['smw_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_smw_dir, fname)
    dst = os.path.join(train_smw_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 smw images to validation_smw_dir
fnames = ['smw_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_smw_dir, fname)
    dst = os.path.join(validation_smw_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Shepherd's Purse Directories and Images

# %%
# Directory with our training shp pictures
train_shp_dir = os.path.join(train_dir, 'shp')
os.mkdir(train_shp_dir)
# Directory with our validation shp pictures
validation_shp_dir = os.path.join(validation_dir, 'shp')
os.mkdir(validation_shp_dir)

#original shp data
original_shp_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/shepherds-purse'

# Copy first 50 shp images to train_shp_dir
fnames = ['shp_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_shp_dir, fname)
    dst = os.path.join(train_shp_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 shp images to validation_shp_dir
fnames = ['shp_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_shp_dir, fname)
    dst = os.path.join(validation_shp_dir, fname)
    shutil.copyfile(src, dst)

# %% [markdown]
# Sugar Beet Directories and Images

# %%
# Directory with our training sbt pictures
train_sbt_dir = os.path.join(train_dir, 'sbt')
os.mkdir(train_sbt_dir)
# Directory with our validation sbt pictures
validation_sbt_dir = os.path.join(validation_dir, 'sbt')
os.mkdir(validation_sbt_dir)

#original sbt data
original_sbt_dir = '/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/sugar-beet'

# Copy first 50 sbt images to train_sbt_dir
fnames = ['sbt_{}.png'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_sbt_dir, fname)
    dst = os.path.join(train_sbt_dir, fname)
    shutil.copyfile(src, dst)

# Copy next 50 sbt images to validation_sbt_dir
fnames = ['sbt_{}.png'.format(i) for i in range(50, 100)]
for fname in fnames:
    src = os.path.join(original_sbt_dir, fname)
    dst = os.path.join(validation_sbt_dir, fname)
    shutil.copyfile(src, dst)
