# %% [markdown]
# # Renaming Files
# This is an optional script which I used to rename my files as when they were downloaded the names were long and random

# %%
# Mount google drive
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np

# %% [markdown]
# **Black Grass**

# %%
# Path to black grass file in /all-data
bgs = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/black-grass"

# %%
# list of current names
bgs_names = np.array(os.listdir(bgs))
print(names)

# %%
# Function to rename the files 
def main(): 
    for count, filename in enumerate(bgs_names): 
        dst = "bgs_" + str(count) + ".png"
        src = bgs + '/' + filename 
        dst = bgs + '/' + dst 
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
    # Calling main() function 
    main()

# %% [markdown]
# The above code chunk is repeated for all 11 remaining species

# %% [markdown]
# **Charlock**

# %%
chk = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/charlock"

# %%
chk_names = np.array(os.listdir(chk))

# %%
def main(): 
    for count, filename in enumerate(chk_names): 
        dst = "chk_" + str(count) + ".png"
        src = chk + '/' + filename 
        dst = chk + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Cleavers**

# %%
cls = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/cleavers"
cls_names = np.array(os.listdir(cls))
def main(): 
    for count, filename in enumerate(cls_names): 
        dst = "cls_" + str(count) + ".png"
        src = cls + '/' + filename 
        dst = cls + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Common Chickweed**

# %%
cwd = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/common-chickweed"
cwd_names = np.array(os.listdir(cwd))
def main(): 
    for count, filename in enumerate(cwd_names): 
        dst = "cwd_" + str(count) + ".png"
        src = cwd + '/' + filename 
        dst = cwd + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Wheat**

# %%
wht = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/common-wheat"
wht_names = np.array(os.listdir(wht))
def main(): 
    for count, filename in enumerate(wht_names): 
        dst = "wht_" + str(count) + ".png"
        src = wht + '/' + filename 
        dst = wht + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Fat Hen**

# %%
fhn = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/fat-hen"
fhn_names = np.array(os.listdir(fhn))
def main(): 
    for count, filename in enumerate(fhn_names): 
        dst = "fhn_" + str(count) + ".png"
        src = fhn + '/' + filename 
        dst = fhn + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Loose Silky Bent**

# %%
lsb = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/loose-silky-bent"
lsb_names = np.array(os.listdir(lsb))
def main(): 
    for count, filename in enumerate(lsb_names): 
        dst = "lsb_" + str(count) + ".png"
        src = lsb + '/' + filename 
        dst = lsb + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Maize**

# %%
mze = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/maize"
mze_names = np.array(os.listdir(mze))
def main(): 
    for count, filename in enumerate(mze_names): 
        dst = "mze_" + str(count) + ".png"
        src = mze + '/' + filename 
        dst = mze + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Scentless Mayweed**

# %%
smw = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/scentless-mayweed"
smw_names = np.array(os.listdir(smw))
def main(): 
    for count, filename in enumerate(smw_names): 
        dst = "smw_" + str(count) + ".png"
        src = smw + '/' + filename 
        dst = smw + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Sheperds Purse**

# %%
shp = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/shepherds-purse"
shp_names = np.array(os.listdir(shp))
def main(): 
    for count, filename in enumerate(shp_names): 
        dst = "shp_" + str(count) + ".png"
        src = shp + '/' + filename 
        dst = shp + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Cranesbill**

# %%
cbl = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/cranesbill"
cbl_names = np.array(os.listdir(cbl))
def main(): 
    for count, filename in enumerate(cbl_names): 
        dst = "cbl_" + str(count) + ".png"
        src = cbl + '/' + filename 
        dst = cbl + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()

# %% [markdown]
# **Sugar Beet**

# %%
sbt = "/content/drive/MyDrive/Harper/3-C7082/Assignment/C7082-assignment/all-data/sugar-beet"
sbt_names = np.array(os.listdir(sbt))
def main(): 
    for count, filename in enumerate(sbt_names): 
        dst = "sbt_" + str(count) + ".png"
        src = sbt + '/' + filename 
        dst = sbt + '/' + dst 
          
        # rename() function will rename all the files 
        os.rename(src, dst) 
# Driver Code 
if __name__ == '__main__': 
      
    # Calling main() function 
    main()
